# %%
# here we will index the dataframes according to our needs

# Library import
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Dataset load
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Sorting Dataset
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
# for more compatibility in operation index naming is crucial for us
df.sample(3)
# Out:
#        job_title_short                        job_title  \
# 625360   Data Engineer                    Data Engineer
# 626569    Data Analyst                     Data Analist
# 110609  Data Scientist  Director, Data Science (Remote)
#
#                    job_location                 job_via job_schedule_type  \
# 625360  Cape Town, South Africa  via BeBee South Africa         Full-time
# 626569              Netherlands               via BeBee         Full-time
# 110609                 Anywhere            via Built In         Full-time
#
#         job_work_from_home          search_location     job_posted_date  \
# 625360               False             South Africa 2023-05-09 12:57:50
# 626569               False              Netherlands 2023-11-29 12:23:43
# 110609                True  Illinois, United States 2023-03-15 00:07:55
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 625360                   True                 False   South Africa
# ...

# %%
# now lets name the index
df.index
df.index.dtype
df.index.name = 'Index'

# %%
# now if we perform sample function
df.sample(2)
# Out:
#              job_title_short               job_title     job_location  \
# Index
# 20113   Senior Data Engineer    Senior Data Engineer      Chicago, IL
# 362097          Data Analyst  Data Science Associate  Porto, Portugal
#
#              job_via job_schedule_type  job_work_from_home search_location  \
# Index
# 20113   via LinkedIn         Full-time               False         Georgia
# 362097   via EMPREGO         Full-time               False        Portugal
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# Index
# 20113  2023-05-16 13:42:33                  False                  True
# 362097 2023-03-30 23:40:11                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# Index
# 20113   United States        None              NaN              NaN
# 362097       Portugal        None              NaN              NaN
#
#                       company_name  \
# Index
# ...

# %%
# now we get the pivot table based on median
median_pivot = df.pivot_table(values='salary_year_avg',index='job_title_short',aggfunc='median')
median_pivot
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %%
# finding the index name
index_name = median_pivot.index.name
index_name
# Out:
# 'job_title_short'

# %%
# finding the index type
index_type = median_pivot.index.dtype
index_type
# Out:
# dtype('O')

# %%
# now to test the reset function on what it does to custom made dataframes lets create one first!
us_dataframe = df[df['job_country'] == 'United States']
us_dataframe
# Out:
#              job_title_short  \
# Index
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# Index
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# ...

# %%
us_dataframe.reset_index(inplace=True)
us_dataframe
# Out:
#          Index       job_title_short  \
# 0            0  Senior Data Engineer
# 1            3         Data Engineer
# 2            5         Data Engineer
# 3            6  Senior Data Engineer
# 4            9        Data Scientist
# ...        ...                   ...
# 206287  785673        Data Scientist
# 206288  785685          Data Analyst
# 206289  785692        Data Scientist
# 206290  785703          Data Analyst
# 206291  785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 1       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 2                                       GCP Data Engineer          Anywhere
# 3                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 4                                       Data Scientist II          Anywhere
# ...

# %%
# same we can do with former median_pivot dataframe
# median_pivot.reset_index(inplace=True)
median_pivot = median_pivot.reset_index(drop=True)
median_pivot
# Out:
#    level_0  index            job_title_short  salary_year_avg
# 0        0      0           Business Analyst          85000.0
# 1        1      1             Cloud Engineer          90000.0
# 2        2      2               Data Analyst          90000.0
# 3        3      3              Data Engineer         125000.0
# 4        4      4             Data Scientist         127500.0
# 5        5      5  Machine Learning Engineer         106415.0
# 6        6      6        Senior Data Analyst         111175.0
# 7        7      7       Senior Data Engineer         147500.0
# 8        8      8      Senior Data Scientist         155500.0
# 9        9      9          Software Engineer          99150.0

# %%
median_pivot = median_pivot.drop(columns=['level_0', 'index']).reset_index(drop=True)
median_pivot
# Out:
#              job_title_short  salary_year_avg
# 0           Business Analyst          85000.0
# 1             Cloud Engineer          90000.0
# 2               Data Analyst          90000.0
# 3              Data Engineer         125000.0
# 4             Data Scientist         127500.0
# 5  Machine Learning Engineer         106415.0
# 6        Senior Data Analyst         111175.0
# 7       Senior Data Engineer         147500.0
# 8      Senior Data Scientist         155500.0
# 9          Software Engineer          99150.0

# %%
# us_dataframe = us_dataframe.drop(columns='Index').reset_index(drop=True)
us_dataframe.index.name = 'job_index'
us_dataframe
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 1                 Data Engineer
# 2                 Data Engineer
# 3          Senior Data Engineer
# 4                Data Scientist
# ...                         ...
# 206287           Data Scientist
# 206288             Data Analyst
# 206289           Data Scientist
# 206290             Data Analyst
# 206291             Data Analyst
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 2                                          GCP Data Engineer
# 3                          Senior Data Engineer  - GCP Cloud
# 4                                          Data Scientist II
# ...                                                      ...
# 206287                       Asset Management Data Scientist
# ...

# %%
# now lets set job index as default index
us_dataframe
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 1                 Data Engineer
# 2                 Data Engineer
# 3          Senior Data Engineer
# 4                Data Scientist
# ...                         ...
# 206287           Data Scientist
# 206288             Data Analyst
# 206289           Data Scientist
# 206290             Data Analyst
# 206291             Data Analyst
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 2                                          GCP Data Engineer
# 3                          Senior Data Engineer  - GCP Cloud
# 4                                          Data Scientist II
# ...                                                      ...
# 206287                       Asset Management Data Scientist
# ...

# %%
median_pivot.sort_index(ascending=True)
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0
