# %% [markdown]
# # Using Skills learnt till now!

# %%
# here are all job roles
job_roles =[
    {'role': 'Data Analyst', 'skills': ['Python', 'SQL', 'Excel']},
    {'role': 'Data Scientist', 'skills': ['Python', 'R', 'Machine Learning', 'Deep Learning']},
    {'role': 'Machine Learning Engineer', 'skills': ['Python', 'TensorFlow', 'PyTorch', 'Scikit-Learn']},
    {'role': 'Data Engineer', 'skills': ['Python', 'Apache Spark', 'Hadoop', 'SQL']},
    {'role': 'Business Intelligence Analyst', 'skills': ['Python', 'SQL', 'Tableau', 'Power BI', 'Excel']},
    {'role': 'Quantitative Analyst', 'skills': ['R', 'Python', 'MATLAB', 'Statistics']},
    {'role': 'Operations Analyst', 'skills': ['Python', 'SQL', 'Data Visualization', 'Process Improvement']},
    {'role': 'Database Administrator', 'skills': ['SQL', 'Oracle', 'MySQL', 'Database Management']},
    {'role': 'AI Engineer', 'skills': ['Python', 'TensorFlow', 'PyTorch', 'Computer Vision']},
    {'role': 'Statistician', 'skills': ['R', 'SAS', 'Python', 'Statistical Modeling']}
]

# %%
# My skills
my_skills = ['Python','SQL','Excel']

# %%
qualified_roles = []
for job in job_roles:
  qualified = True
  for skill in my_skills:
    if skill not in job['skills']:
      qualified = False
      break
  if qualified:
    qualified_roles.append(job['role'])
qualified_roles
# Out:
# ['Data Analyst', 'Business Intelligence Analyst']

# %%
# Determine which jobs you're qualified for
qualified_roles = []

for job in job_roles:
    # Check if all required skills are in my_skills
    if all(skill in job['skills'] for skill in my_skills):
        # Add the job role to the qualified_roles list
        qualified_roles.append(job['role'])

qualified_roles
# Out:
# ['Data Analyst', 'Business Intelligence Analyst']

# %%
if qualified_roles:
  output_message = f"Qualified for the following roles: {', '.join(qualified_roles)}"
else:
  output_message = "Not qualified for any roles."
output_message
# Out:
# 'Qualified for the following roles: Data Analyst, Business Intelligence Analyst'

# %% [markdown]
# # Functions

# %%
# So now we will start with the functions
print('All is Well')
# Out:
# All is Well

# %%
# to make a custom function we have define it properly
def intro():
  print('How was your day?')
intro()
# Out:
# How was your day?

# %%
# some common functions for Data Analytics
salary = [95000, 120000, 105000, 90000, 130000]
total = sum(salary)
minimum = min(salary)
maximum = max (salary)
print(f'Total Salary: ${total}, Minimum: ${minimum}, Maximum: ${maximum}')
# Out:
# Total Salary: $540000, Minimum: $90000, Maximum: $130000

# %%
years_experience = [2, 5, 3, 4, 1]
sort = sorted(years_experience)
sort
# Out:
# [1, 2, 3, 4, 5]

# %%
# using some kind of placeholder
def job_role(title):
  print(f'I am a {title}')
job_role('Data Analyst')
# Out:
# I am a Data Analyst

# %% [markdown]
# # Lambda Functions

# %%
# As Lambda functions can be sunccint we can use them, lets use it
# define a lambda function to add two numbers
add = lambda x, y: x + y

# %%
# Now lets check it
add(4,5)
# Out:
# 9

# %%
# Second Concept
salary_list = [95000, 120000, 105000, 90000]
# Now calculate the total_salary based on base_salary * (1 + bonus_rate)
def calculate_salary(base_salary, bonus_rate=.1):
  return base_salary * (1 + bonus_rate)
total_salary_list = [calculate_salary(salary) for salary in salary_list]
total_salary_list
# Out:
# [104500.00000000001, 132000.0, 115500.00000000001, 99000.00000000001]

# %%
# Alternate method
total_salary_list = [salary * 1.1 for salary in salary_list]
total_salary_list
# Out:
# [104500.00000000001, 132000.0, 115500.00000000001, 99000.00000000001]

# %%
jobs_data = [
    {'job_title': 'Data Scientist',  'job_skills': ['Python', 'Machine Learning'], 'remote': True},
    {'job_title': 'Data Analyst',  'job_skills': ['Excel', 'SQL'], 'remote': False},
    {'job_title': 'Machine Learning Engineer', 'job_skills': ['Python', 'TensorFlow', 'Keras'], 'remote': True},
    {'job_title': 'Software Developer', 'job_skills': ['Java', 'C++'], 'remote': True},
    {'job_title': 'Data Scientist', 'job_skills': ['R', 'Statistics'], 'remote': False}
]

# %%
# lets test only remote jobs
list(filter(lambda job: job['remote'],jobs_data))
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': ['Python', 'Machine Learning'],
#   'remote': True},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': ['Python', 'TensorFlow', 'Keras'],
#   'remote': True},
#  {'job_title': 'Software Developer',
#   'job_skills': ['Java', 'C++'],
#   'remote': True}]

# %%
# now we want to find out jobs which are remote and requires python
filter_criteria = lambda job: 'Python' in job['job_skills'] and job['remote']
# Apply the filter
python_remote_jobs = list(filter(filter_criteria, jobs_data))
for job in python_remote_jobs:
  print(job)
# Out:
# {'job_title': 'Data Scientist', 'job_skills': ['Python', 'Machine Learning'], 'remote': True}
# {'job_title': 'Machine Learning Engineer', 'job_skills': ['Python', 'TensorFlow', 'Keras'], 'remote': True}
