# %%
90000
# Out:
# 90000

# %%
"Data Nerd"
# Out:
# 'Data Nerd'

# %%
type("Data Nerd")
# Out:
# str

# %%
job_title = "Data Analyst"
job_salary = 90000
my_print_function = print

# %%
my_print_function(job_title, job_salary)
# Out:
# Data Analyst 90000

# %%
id(job_title), id(job_salary), id(my_print_function)
# Out:
# (138519446314800, 138519446294896, 138520158850640)

# %%
praveen_job = job_title

# %%
praveen_job
# Out:
# 'Data Analyst'

# %%
id(praveen_job), id(job_title)
# Out:
# (138519446314800, 138519446314800)

# %%
def greet() :
  return "What's up Praveen"

# %%
greet()
# Out:
# "What's up Praveen"
