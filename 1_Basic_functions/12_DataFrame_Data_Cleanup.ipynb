# %%
# let get down to cleaning part of the dataframes

# %%
import pandas as pd

# %%
from datasets import load_dataset

# %%
# now lets define the dataset
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
# now we want to change type of job posted date to date and time (pd.to_datetime)
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
# suppose we want only date format (dt.date)
df['job_posted_date'] = df['job_posted_date'].dt.date
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location job_posted_date  \
# ...

# %%
# First, let's restore df since it became None
df = dataset['train'].to_pandas()
df['job_posted_date'] = pd.to_datetime(df['job_posted_date']).dt.date

# Now we sort it correctly using inplace=True without assigning it back to df
df.sort_values(by='job_posted_date', inplace=True)

# Check the result
df.head()
# Out:
#              job_title_short  \
# 461362        Data Scientist
# 274144        Data Scientist
# 364349          Data Analyst
# 364347  Senior Data Engineer
# 346928        Cloud Engineer
#
#                                                 job_title       job_location  \
# 461362  Turing Hiring Near Me – Remote Data Scientist ...      Palo Alto, CA
# 274144  STAGE - Assistant(e) Data Scientist – Quantum ...  Montrouge, France
# 364349                 Functional analyst Adobe Analytics      Madrid, Spain
# 364347          Senior Data Engineer (Innovation Insurer)          Hong Kong
# 346928  Data Center Storage with Avamar/Sacramento, CA...     Sacramento, CA
#
#                       job_via job_schedule_type  job_work_from_home  \
# 461362         via Jobs Picks         Full-time               False
# 274144              via BeBee        Internship               False
# 364349        via Recruit.net         Full-time               False
# ...

# %%
# Ensure the column is a datetime type first to use the .dt accessor
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# Extract the month number (1 for Jan, 12 for Dec)
df['month_number'] = df['job_posted_date'].dt.month

# Display the change
df[['job_posted_date', 'month_number']].head()
# Out:
#        job_posted_date  month_number
# 461362      2023-01-01             1
# 274144      2023-01-01             1
# 364349      2023-01-01             1
# 364347      2023-01-01             1
# 346928      2023-01-01             1

# %%
df
# Out:
#                   job_title_short  \
# 461362             Data Scientist
# 274144             Data Scientist
# 364349               Data Analyst
# 364347       Senior Data Engineer
# 346928             Cloud Engineer
# ...                           ...
# 61924   Machine Learning Engineer
# 646083             Data Scientist
# 411096             Data Scientist
# 702239               Data Analyst
# 103131               Data Analyst
#
#                                                 job_title  \
# 461362  Turing Hiring Near Me – Remote Data Scientist ...
# 274144  STAGE - Assistant(e) Data Scientist – Quantum ...
# 364349                 Functional analyst Adobe Analytics
# 364347          Senior Data Engineer (Innovation Insurer)
# 346928  Data Center Storage with Avamar/Sacramento, CA...
# ...                                                   ...
# 61924                         Senior/Staff MLOps Engineer
# 646083  DATA SCIENTIST regio Utrecht – PHARMO Institut...
# ...

# %%
# lets check for data analyst only
df[df['job_title_short']=='Data Analyst']
# Out:
#        job_title_short                           job_title  \
# 364349    Data Analyst  Functional analyst Adobe Analytics
# 732186    Data Analyst            Data & Analytics Analyst
# 346874    Data Analyst    Technical Business/ Data Analyst
# 404115    Data Analyst               Data Analyst - Onsite
# 188178    Data Analyst                        Data Analyst
# ...                ...                                 ...
# 94222     Data Analyst                    Data Analyst III
# 728684    Data Analyst               Data Analyst- Payroll
# 392000    Data Analyst                        Data Analyst
# 702239    Data Analyst              Technical Data Analyst
# 103131    Data Analyst              Principal data analyst
#
#                              job_location              job_via  \
# 364349                      Madrid, Spain      via Recruit.net
# 732186                     Warsaw, Poland      via Trabajo.org
# 346874                   Philadelphia, PA         via LinkedIn
# ...

# %%
# now i want to remove empty values from salary_year_avg column
df_delete_empty = df.dropna(subset=['salary_year_avg'],inplace=False)
df_delete_empty
# Out:
#               job_title_short  \
# 776813  Senior Data Scientist
# 777985          Data Engineer
# 69156          Data Scientist
# 334082          Data Engineer
# 2862           Data Scientist
# ...                       ...
# 714269         Data Scientist
# 22280     Senior Data Analyst
# 250599           Data Analyst
# 336301         Data Scientist
# 702239           Data Analyst
#
#                                                 job_title  \
# 776813                              Senior Data Scientist
# 777985         Data Engineer - Spark, Scala, Kafka, Flink
# 69156                                Staff Data Scientist
# 334082                                      Data Engineer
# 2862                             Marketing Data Scientist
# ...                                                   ...
# 714269                                  Data Science Lead
# 22280   Lead Data Analyst/Senior Data Analyst, Tiktok ...
# 250599                     Supply Chain Analytics Manager
# ...

# %%
df
# Out:
#                   job_title_short  \
# 461362             Data Scientist
# 274144             Data Scientist
# 364349               Data Analyst
# 364347       Senior Data Engineer
# 346928             Cloud Engineer
# ...                           ...
# 61924   Machine Learning Engineer
# 646083             Data Scientist
# 411096             Data Scientist
# 702239               Data Analyst
# 103131               Data Analyst
#
#                                                 job_title  \
# 461362  Turing Hiring Near Me – Remote Data Scientist ...
# 274144  STAGE - Assistant(e) Data Scientist – Quantum ...
# 364349                 Functional analyst Adobe Analytics
# 364347          Senior Data Engineer (Innovation Insurer)
# 346928  Data Center Storage with Avamar/Sacramento, CA...
# ...                                                   ...
# 61924                         Senior/Staff MLOps Engineer
# 646083  DATA SCIENTIST regio Utrecht – PHARMO Institut...
# ...

# %%
# Filter the dataframe to exclude 'Contractor' jobs
df_no_contractor = df_delete_empty[df_delete_empty['job_schedule_type'] != 'Contractor']

# Display the result to verify
df_no_contractor
# Out:
#               job_title_short  \
# 776813  Senior Data Scientist
# 777985          Data Engineer
# 69156          Data Scientist
# 334082          Data Engineer
# 705374         Data Scientist
# ...                       ...
# 714269         Data Scientist
# 22280     Senior Data Analyst
# 250599           Data Analyst
# 336301         Data Scientist
# 702239           Data Analyst
#
#                                                 job_title  \
# 776813                              Senior Data Scientist
# 777985         Data Engineer - Spark, Scala, Kafka, Flink
# 69156                                Staff Data Scientist
# 334082                                      Data Engineer
# 705374                               Data Science Manager
# ...                                                   ...
# 714269                                  Data Science Lead
# 22280   Lead Data Analyst/Senior Data Analyst, Tiktok ...
# 250599                     Supply Chain Analytics Manager
# ...

# %%
df
# Out:
#                   job_title_short  \
# 461362             Data Scientist
# 274144             Data Scientist
# 364349               Data Analyst
# 364347       Senior Data Engineer
# 346928             Cloud Engineer
# ...                           ...
# 61924   Machine Learning Engineer
# 646083             Data Scientist
# 411096             Data Scientist
# 702239               Data Analyst
# 103131               Data Analyst
#
#                                                 job_title  \
# 461362  Turing Hiring Near Me – Remote Data Scientist ...
# 274144  STAGE - Assistant(e) Data Scientist – Quantum ...
# 364349                 Functional analyst Adobe Analytics
# 364347          Senior Data Engineer (Innovation Insurer)
# 346928  Data Center Storage with Avamar/Sacramento, CA...
# ...                                                   ...
# 61924                         Senior/Staff MLOps Engineer
# 646083  DATA SCIENTIST regio Utrecht – PHARMO Institut...
# ...

# %%
# Delete the row with index 702239
df.drop(index=702239, inplace=False)

# Verify it's gone by checking the last few rows where it was previously visible
df.tail()
# Out:
#                   job_title_short  \
# 61924   Machine Learning Engineer
# 646083             Data Scientist
# 411096             Data Scientist
# 702239               Data Analyst
# 103131               Data Analyst
#
#                                                 job_title  \
# 61924                         Senior/Staff MLOps Engineer
# 646083  DATA SCIENTIST regio Utrecht – PHARMO Institut...
# 411096                          Data Scientist Specialist
# 702239                             Technical Data Analyst
# 103131                             Principal data analyst
#
#                              job_location           job_via job_schedule_type  \
# 61924                          Denver, CO         via BeBee         Full-time
# 646083            Nieuwegein, Netherlands  via Utrecht.work         Full-time
# 411096                          Argentina      via LinkedIn         Full-time
# 702239  Manila, Metro Manila, Philippines   via Ai-Jobs.net         Full-time
# ...
